# %%
tasks = []

while True:
    print("\n--- TO DO APP ---")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Delete Task")
    print("4. Exit")

    choice = input("Enter your choice (1-4): ")

    if choice == "1":
        task = input("Enter a new task: ")
        tasks.append(task)
        print("Task added successfully!")

    elif choice == "2":
        if len(tasks) == 0:
            print("No tasks available.")
        else:
            print("\nYour Tasks:")
            for i in range(len(tasks)):
                print(f"{i + 1}. {tasks[i]}")

    elif choice == "3":
        if len(tasks) == 0:
            print("No tasks to delete.")
        else:
            for i in range(len(tasks)):
                print(f"{i + 1}. {tasks[i]}")

            delete_task = int(input("Enter task number to delete: "))
            if delete_task > 0 and delete_task <= len(tasks):
                removed = tasks.pop(delete_task - 1)
                print(f"Removed task: {removed}")
            else:
                print("Invalid task number.")

    elif choice == "4":
        print("Exiting To-Do App. Goodbye!")
        break

    else:
        print("Invalid choice. Please select 1-4.")
# Out:
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 1
# Enter a new task: hello
# Task added successfully!
#
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 2
#
# Your Tasks:
# 1. hello
#
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 4
# Exiting To-Do App. Goodbye!

# %%
#calculator app
print("""
welcome to my first calculator
press 1 for addition
press 2 for subtraction
press 3 for multiplication
press 4 for divisoni
thank you
""")

choice = int(input("enter your choice from 1-4 :   "))
nomi1 = int(input("enter your 1 number : "))
nomi2 = int(input("enter your 2 number: "))
large = max(nomi1 , nomi2)
small = min(nomi1,nomi2)

if (choice==1):
  print("your addition resullt:",nomi1 + nomi2)
elif (choice == 2):
 result1=large-small
 print("your substraction result",result1)
elif(choice==3):
    print("your multiply result",nomi1*nomi2)
elif(choice==4):
  #if small == 0:
    #print("divison by zero is not possible in python")
  print("your divison result",large/small)



print("thankyou")
# Out:
# welcome to my first calculator
# press 1 for addition
# press 2 for subtraction
# press 3 for multiplication
# press 4 for divisoni
# thank you
#
# enter your choice from 1-4 :   4
# enter your 1 number : 98
# enter your 2 number: 3
# your divison result 32.666666666666664
# thankyou
